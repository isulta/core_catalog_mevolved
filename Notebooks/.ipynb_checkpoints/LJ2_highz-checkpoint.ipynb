# %% [markdown]
# # Load data

# %%
def load_data_highz(step):
    sh_vars = ['fof_halo_tag','subhalo_mean_vx', 'subhalo_mean_vy', 'subhalo_mean_vz', 'subhalo_count', 'subhalo_tag', 'subhalo_mass', 'fof_halo_count']
    
    cc_SV = h5_read_dict('/home/isultan/projects/halomassloss/core_catalog_mevolved/output_LJDS_localhost_dtfactor_0.5_fitting2/m000p-{}.corepropertiesextend.hdf5'.format(step), 'coredata')
    cc_SV['infall_sod_halo_cdelta'] = gio.gio_read('/home/isultan/data/LJDS/CoreCatalog/m000p-{}.coreproperties'.format(step), 'infall_sod_halo_cdelta')[0]
    sh_SV = gio_read_dict('/home/isultan/data/SHfindertests/SV_new_redshifts/m000p-{}.subhaloproperties'.format(step), sh_vars)
    
    for sh, label in [ (sh_SV, 'SV') ]:
        sh['M'] = sh['fof_halo_count']*PARTICLEMASS[label]

    centrals_mask_SV = cc_SV['central'] == 1

    for cc, centrals_mask in [(cc_SV, centrals_mask_SV)]:
        idx_m21_cc = many_to_one(cc['tree_node_index'], cc['tree_node_index'][centrals_mask])
        for hk, k in CC_HOST_VARS:
            cc[hk] = cc[k][centrals_mask][idx_m21_cc]

    return cc_SV, sh_SV, centrals_mask_SV

# %%
# %time (cc_SV2, sh_SV2, centrals_mask_SV2) = load_data_highz(163)
# %time (cc_SV3, sh_SV3, centrals_mask_SV3) = load_data_highz(121)
# %time (cc_SV4, sh_SV4, centrals_mask_SV4) = load_data_highz(97)
# Out:
# CPU times: user 21.6 s, sys: 2.82 s, total: 24.4 s
# Wall time: 3.79 s
# CPU times: user 19.9 s, sys: 1.84 s, total: 21.7 s
# Wall time: 2.28 s
# CPU times: user 14.3 s, sys: 1.18 s, total: 15.5 s
# Wall time: 1.41 s

# %%
cc_sh_list = [(cc_SV0, sh_SV0, centrals_mask_SV0, '$z=0$'), (cc_SV1, sh_SV1, centrals_mask_SV1, '$z=1$'), (cc_SV2, sh_SV2, centrals_mask_SV2, '$z=2$'), (cc_SV3, sh_SV3, centrals_mask_SV3, '$z=3$'), (cc_SV4, sh_SV4, centrals_mask_SV4, '$z=4$')]

# %% [markdown]
# # SHMFs

# %% [markdown]
# ## SV log(m)

# %%
for cc_SV, sh_SV, centrals_mask_SV, zlabel in cc_sh_list:
    resolution_tests_highz(cc_SV, sh_SV, centrals_mask_SV, mplot=True, zlabel=zlabel, smallRatioYaxis=True, assert_nH=False)#, dlM=0.5, logMlist=(12,13,14), )
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 35236
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# /home/isultan/projects/itk/itk.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ebars_log = 1./np.log(10) * np.sqrt(cnts)/cnts
# /home/isultan/projects/itk/itk.py:177: RuntimeWarning: divide by zero encountered in log10
#   cnts = np.log10(cnts)
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:842: RuntimeWarning: invalid value encountered in subtract
# /home/isultan/projects/itk/itk.py:260: RuntimeWarning: invalid value encountered in true_divide
#   return np.sqrt( (nerr/nfid)**2 + (n*nfiderr/nfid**2)**2 )
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 36337
# Mavg (sh centrals): 1.6754462182588432e+13
# ...

# %% [markdown]
# ## SV log(m/M)

# %%
for cc_SV, sh_SV, centrals_mask_SV, zlabel in cc_sh_list:
    resolution_tests_highz(cc_SV, sh_SV, centrals_mask_SV, zlabel=zlabel, smallRatioYaxis=True, assert_nH=False)#, dlM=0.5, logMlist=(12,13,14), )
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 35236
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# SV lim: -1.134210603304881
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:31: RuntimeWarning: invalid value encountered in subtract
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 36337
# Mavg (sh centrals): 1.6754462182588432e+13
# 1.0835104405187458e-05 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# SV lim: -2.1270264045403824
# SV nH cores 337
# Mavg (cores centrals): 1.6433545e+14
# SV nH_sh 337
# SV number of subhalos in bin 21791
# Mavg (sh centrals): 1.6433543829330672e+14
# 5.885759698002493e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# ...

# %% [markdown]
# # A fitting: SV log(m)

# %%
rlim_SV_highz_mplot = np.log10(OBJECTMASSCUT['SV'])
rdict_SV_highz_mplot = {12:(rlim_SV_highz_mplot, 11.9), 13:(rlim_SV_highz_mplot, 12.5)}
M1dict_SV_highz_mplot = {12:10**12.0, 13:10**13.0}
M2dict_SV_highz_mplot = {12:10**12.5, 13:10**13.5}
mlim_SV_highz_mplot = OBJECTMASSCUT['SV']

# %%
ReducedChi2_SV_highz_list_12 = []
ReducedChi2_SV_highz_list_13 = []
for cc_SV, sh_SV, centrals_mask_SV, zlabel in cc_sh_list:
    print(zlabel)
    ReducedChi2dict_SV_highz = ReducedChi2dict_gen_highz(cc_SV, sh_SV, centrals_mask_SV, 'SV',
                                                         rdict_SV_highz_mplot if (zlabel != '$z=4$') else {12:rdict_SV_highz_mplot[12]},
                                                         M1dict_SV_highz_mplot,
                                                         M2dict_SV_highz_mplot, 
                                                         mlim=mlim_SV_highz_mplot, mplot=True, dlog=False)
    ReducedChi2_SV_highz_list_12.append(ReducedChi2dict_SV_highz[12])
    if zlabel != '$z=4$':
        ReducedChi2_SV_highz_list_13.append(ReducedChi2dict_SV_highz[13])
# Out:
# $z=0$
# SV nH cores 40628
# SV nH_sh 40628
# SV number of subhalos in bin 8964
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:12.
#
# SV nH cores 4797
# SV nH_sh 4797
# SV number of subhalos in bin 11395
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:13.
#
# $z=1$
# SV nH cores 34592
# SV nH_sh 34592
# SV number of subhalos in bin 9485
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:12.
#
# SV nH cores 2418
# SV nH_sh 2418
# SV number of subhalos in bin 6816
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:13.
#
# $z=2$
# SV nH cores 20780
# SV nH_sh 20780
# SV number of subhalos in bin 5599
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:12.
#
# SV nH cores 562
# SV nH_sh 562
# SV number of subhalos in bin 1323
# RELDIF: 0.0% between nH_cores and nH_sh for Mlabel:13.
#
# $z=3$
# SV nH cores 8295
# SV nH_sh 8236
# SV number of subhalos in bin 2205
# RELDIF: 0.7138104167926925% between nH_cores and nH_sh for Mlabel:12.
#
# SV nH cores 49
# SV nH_sh 49
# ...

# %%
fig = plt.figure()
errorbar(fig.gca(), *bestA_highz_gen(ReducedChi2_SV_highz_list_12), label='$M \in$ [12.0, 12.5]', marker='o', alpha=1.0)
errorbar(fig.gca(), *bestA_highz_gen(ReducedChi2_SV_highz_list_13), label='$M \in$ [13.0, 13.5]', marker='s', alpha=1.0)

plt.axhline(AFID, ls=':', c='k', label='fiducial $\mathcal{A}$')

plt.legend()
plt.xlabel('$z$')
plt.ylabel('$\mathcal{A}$')
# Out:
# z=0
# ReducedChi2.min: 1.2262632719405608
# best A: 1.1
# [1.  1.1]
#
# z=1
# ReducedChi2.min: 1.3407599800631675
# best A: 1.3
# [1.3]
#
# z=2
# ReducedChi2.min: 1.7774019777684098
# best A: 2.0
# [1.8 1.9 2.  2.1]
#
# z=3
# ReducedChi2.min: 0.7093827557204292
# best A: 2.2
# [2.1 2.2 2.3 2.4]
#
# z=4
# ReducedChi2.min: 1.3930874411309773
# best A: 2.4
# [2.2 2.3 2.4]
#
# z=0
# ReducedChi2.min: 2.5213770015608397
# best A: 1.3
# [1.3 1.4]
#
# z=1
# ReducedChi2.min: 4.481544782583505
# best A: 1.3
# [1.2 1.3 1.4]
#
# z=2
# ReducedChi2.min: 0.9305345958600933
# best A: 2.1
# [1.8 1.9 2.  2.1 2.2 2.3 2.4]
#
# z=3
# ReducedChi2.min: 0.9343490648557219
# best A: 2.4
# [1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]
# Text(0, 0.5, '$\\mathcal{A}$')
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## best-fit A SHMFs

# %%
_, bestA_arr_12, _ = bestA_highz_gen(ReducedChi2_SV_highz_list_12)
_, bestA_arr_13, _ = bestA_highz_gen(ReducedChi2_SV_highz_list_13)
# Out:
# z=0
# ReducedChi2.min: 1.2262632719405608
# best A: 1.1
# [1.  1.1]
#
# z=1
# ReducedChi2.min: 1.3407599800631675
# best A: 1.3
# [1.3]
#
# z=2
# ReducedChi2.min: 1.7774019777684098
# best A: 2.0
# [1.8 1.9 2.  2.1]
#
# z=3
# ReducedChi2.min: 0.7093827557204292
# best A: 2.2
# [2.1 2.2 2.3 2.4]
#
# z=4
# ReducedChi2.min: 1.3930874411309773
# best A: 2.4
# [2.2 2.3 2.4]
#
# z=0
# ReducedChi2.min: 2.5213770015608397
# best A: 1.3
# [1.3 1.4]
#
# z=1
# ReducedChi2.min: 4.481544782583505
# best A: 1.3
# [1.2 1.3 1.4]
#
# z=2
# ReducedChi2.min: 0.9305345958600933
# best A: 2.1
# [1.8 1.9 2.  2.1 2.2 2.3 2.4]
#
# z=3
# ReducedChi2.min: 0.9343490648557219
# best A: 2.4
# [1.5 1.6 1.7 1.8 1.9 2.  2.1 2.2 2.3 2.4]

# %%
bestA_arr_12
# Out:
# array([1.1, 1.3, 2. , 2.2, 2.4])

# %%
for A, (cc_SV, sh_SV, centrals_mask_SV, zlabel) in zip(bestA_arr_12, cc_sh_list):
    resolution_tests_highz(cc_SV, sh_SV, centrals_mask_SV, mplot=True, zlabel=zlabel, smallRatioYaxis=True, assert_nH=False, A=A, zeta=ZETAFID)
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 35236
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# /home/isultan/projects/itk/itk.py:161: RuntimeWarning: invalid value encountered in true_divide
#   ebars_log = 1./np.log(10) * np.sqrt(cnts)/cnts
# /home/isultan/projects/itk/itk.py:177: RuntimeWarning: divide by zero encountered in log10
#   cnts = np.log10(cnts)
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:842: RuntimeWarning: invalid value encountered in subtract
# /home/isultan/projects/itk/itk.py:260: RuntimeWarning: invalid value encountered in true_divide
#   return np.sqrt( (nerr/nfid)**2 + (n*nfiderr/nfid**2)**2 )
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 36337
# Mavg (sh centrals): 1.6754462182588432e+13
# ...

# %%
bestA_arr_13
# Out:
# array([1.3, 1.3, 2.1, 2.4])

# %%
for A, (cc_SV, sh_SV, centrals_mask_SV, zlabel) in zip(bestA_arr_13, cc_sh_list):
    resolution_tests_highz(cc_SV, sh_SV, centrals_mask_SV, mplot=True, zlabel=zlabel, smallRatioYaxis=True, assert_nH=False, A=A, zeta=ZETAFID)
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 35236
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:32: RuntimeWarning: invalid value encountered in subtract
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 36337
# Mavg (sh centrals): 1.6754462182588432e+13
# 1.0835104405187458e-05 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# SV nH cores 337
# Mavg (cores centrals): 1.6433545e+14
# SV nH_sh 337
# SV number of subhalos in bin 21791
# Mavg (sh centrals): 1.6433543829330672e+14
# 5.885759698002493e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# ax1 YLIM (-3.0, 3.6)
# SV nH cores 34592
# Mavg (cores centrals): 1.6771427e+12
# ...

# %% [markdown]
# ## z=0 best-fit A SHMFs (Sec. 5.4)

# %%
for A, (cc_SV, sh_SV, centrals_mask_SV, zlabel) in zip(bestA_arr_12, cc_sh_list):
    resolution_tests_highz(cc_SV, sh_SV, centrals_mask_SV, 
                           mplot=True, 
                           A=A, zeta=ZETAFID,
                           fixedAxis=False,
                           zlabel=zlabel+ r', $(\mathcal{A},\zeta)=$ '+f'({A}, {ZETAFID})', 
                           smallRatioYaxis=True, 
                           assert_nH=False,
                           r=(rlim_SV_highz_mplot,13.12),
                           logMlist=(12, 13), 
                           mlim=mlim_SV_highz_mplot,
                           bins=20,
                           ax_xlim=(rlim_SV_highz_mplot,13.12),
                           ax_ylim=(-3.84,1.3011),
                           draw_vline=False)
#     plt.savefig(f'Paper2Figs/highz_SV_z_{zlabel[-2]}.pdf')
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 8964
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:842: RuntimeWarning: invalid value encountered in subtract
# No handles with labels found to put in legend.
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 11395
# Mavg (sh centrals): 1.6754462182588432e+13
# 1.0835104405187458e-05 percent relative difference between Mavg_cores and Mavh_sh
#
# RELDIF: 0.0%
# ax1 YLIM (-3.84, 1.3011)
# ax1 XLIM (11.097104087023157, 13.12)
# SV nH cores 34592
# Mavg (cores centrals): 1.6771427e+12
# SV nH_sh 34592
# SV number of subhalos in bin 9485
# Mavg (sh centrals): 1.6771425055584014e+12
# ...

# %%
exec(open('paper2plotscripts.py').read())
for A, (cc_SV, sh_SV, centrals_mask_SV, zlabel) in zip(bestA_arr_12, cc_sh_list):
    highz_plot(cc_SV, sh_SV, centrals_mask_SV, 
               A=A, zeta=ZETAFID,
               logMlist=(12, 13),
               zlabel=zlabel,
               newlegend=(zlabel[-2]=='0'))
#     plt.savefig(f'Paper2Figs/highz_SV_combined_z_{zlabel[-2]}.pdf')
# Out:
# SV nH cores 40628
# Mavg (cores centrals): 1.7033924e+12
# SV nH_sh 40628
# SV number of subhalos in bin 8964
# Mavg (sh centrals): 1.7033923415564163e+12
# 6.0385137425623816e-06 percent relative difference between Mavg_cores and Mavh_sh
# RELDIF: 0.0% between nH_cores and nH_sh for logM1:12.
# /home/isultan/miniconda3/envs/smacc/lib/python3.7/site-packages/ipykernel_launcher.py:917: RuntimeWarning: invalid value encountered in subtract
# SV nH cores 4797
# Mavg (cores centrals): 1.6754464e+13
# SV nH_sh 4797
# SV number of subhalos in bin 11395
# Mavg (sh centrals): 1.6754462182588432e+13
# 1.0835104405187458e-05 percent relative difference between Mavg_cores and Mavh_sh
# RELDIF: 0.0% between nH_cores and nH_sh for logM1:13.
# SV nH cores 34592
# Mavg (cores centrals): 1.6771427e+12
# SV nH_sh 34592
# SV number of subhalos in bin 9485
# Mavg (sh centrals): 1.6771425055584014e+12
# 8.909057607314903e-06 percent relative difference between Mavg_cores and Mavh_sh
# ...

# %% [markdown]
# # Hiroshima et al. 2018

# %%
def A_H18(M, z):
    return np.power(10, (-0.0003*np.log10(M)+0.02)*z + 0.011*np.log10(M) - 0.354)

# %%
def zeta_H18(M, z):
    return (0.00012*np.log10(M)-0.0033)*z - 0.0011*np.log10(M) + 0.026

# %%
zarr_H18 = np.linspace(0,7)

# %%
plt.xlabel('z')
plt.ylabel('A')

for lM in (15, 14, 13, 12):
    plt.plot(zarr_H18, A_H18(10**lM, zarr_H18), label='$\log M/M_{\odot}=$'+str(lM))
plt.legend()

# %%
plt.xlabel('z')
plt.ylabel('$\zeta$')

for lM in (15, 14, 13, 12):
    plt.plot(zarr_H18, zeta_H18(10**lM, zarr_H18), label='$\log M/M_{\odot}=$'+str(lM))
plt.legend()
